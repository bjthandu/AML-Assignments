# %%
import os
import pathlib
import shutil
import random
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# %%
# Setting random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# %% [markdown]
# # ===============================================
# # PART 1: DATA PREPARATION
# # ===============================================

# %%
def prepare_data():
    """Download and prepare the IMDB dataset"""
    print("=" * 80)
    print("PART 1: DATA PREPARATION")
    print("=" * 80)

    # Download data
    if not os.path.exists("aclImdb"):
        print("Downloading IMDB dataset...")
        os.system("curl -O https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz")
        os.system("tar -xf aclImdb_v1.tar.gz")
        os.system("rm -r aclImdb/train/unsup")

    # Assignment requirements
    batch_size = 32
    base_dir = pathlib.Path("aclImdb")
    val_dir = base_dir / "val"
    train_dir = base_dir / "train"

    # Create validation directory
    if not os.path.exists(val_dir):
        for category in ("neg", "pos"):
            os.makedirs(val_dir / category, exist_ok=True)
            files = os.listdir(train_dir / category)
            random.Random(1337).shuffle(files)
            num_val_samples = int(0.2 * len(files))
            val_files = files[-num_val_samples:]
            for fname in val_files:
                shutil.move(train_dir / category / fname,
                          val_dir / category / fname)

    # Load datasets
    train_ds = keras.utils.text_dataset_from_directory(
        "aclImdb/train", batch_size=batch_size
    )
    val_ds = keras.utils.text_dataset_from_directory(
        "aclImdb/val", batch_size=batch_size
    )
    test_ds = keras.utils.text_dataset_from_directory(
        "aclImdb/test", batch_size=batch_size
    )

    return train_ds, val_ds, test_ds

def prepare_limited_dataset(train_ds, val_ds, test_ds,
                           max_length=150, max_tokens=10000,
                           num_train_samples=100, num_val_samples=10000):
    """
    Prepare datasets with assignment constraints:
    - Cutoff reviews after 150 words
    - Restrict training samples to 100
    - Validate on 10,000 samples
    - Consider only top 10,000 words
    """
    print(f"\nPreparing limited dataset:")
    print(f"  Max sequence length: {max_length}")
    print(f"  Max tokens: {max_tokens}")
    print(f"  Training samples: {num_train_samples}")
    print(f"  Validation samples: {num_val_samples}")

    # Extract text for vectorization adaptation
    text_only_train_ds = train_ds.map(lambda x, y: x)

    # Text vectorization layer
    text_vectorization = layers.TextVectorization(
        max_tokens=max_tokens,
        output_mode="int",
        output_sequence_length=max_length,
    )
    text_vectorization.adapt(text_only_train_ds)

    # Vectorize datasets
    int_train_ds = train_ds.map(
        lambda x, y: (text_vectorization(x), y),
        num_parallel_calls=4)
    int_val_ds = val_ds.map(
        lambda x, y: (text_vectorization(x), y),
        num_parallel_calls=4)
    int_test_ds = test_ds.map(
        lambda x, y: (text_vectorization(x), y),
        num_parallel_calls=4)

    # Limit training samples
    int_train_ds_limited = int_train_ds.take(num_train_samples // 32 + 1)

    # Limit validation samples
    int_val_ds_limited = int_val_ds.take(num_val_samples // 32 + 1)

    return (int_train_ds_limited, int_val_ds_limited, int_test_ds,
            text_vectorization, max_tokens, max_length)

# %% [markdown]
# # ===============================================
# # PART 2: MODEL WITH LEARNED EMBEDDING LAYER
# # ===============================================

# %%
def build_model_with_embedding(max_tokens, max_length, embedding_dim=256):
    """Build model with learned embedding layer"""
    print(f"\nBuilding model with learned embedding (dim={embedding_dim})...")

    inputs = keras.Input(shape=(None,), dtype="int64")
    embedded = layers.Embedding(
        input_dim=max_tokens,
        output_dim=embedding_dim,
        mask_zero=True
    )(inputs)
    x = layers.Bidirectional(layers.LSTM(32))(embedded)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer="rmsprop",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %% [markdown]
# # ===================================================
# # PART 3: MODEL WITH PRETRAINED GLOVE EMBEDDINGS
# # ===================================================

# %%
def load_glove_embeddings(embedding_dim=100):
    """Load GloVe pretrained embeddings"""
    glove_file = f"glove.6B.{embedding_dim}d.txt"

    if not os.path.exists(glove_file):
        print("Downloading GloVe embeddings...")
        os.system("wget http://nlp.stanford.edu/data/glove.6B.zip")
        os.system("unzip -q glove.6B.zip")

    print(f"Loading GloVe embeddings from {glove_file}...")
    embeddings_index = {}
    with open(glove_file, encoding='utf-8') as f:
        for line in f:
            word, coefs = line.split(maxsplit=1)
            coefs = np.fromstring(coefs, "f", sep=" ")
            embeddings_index[word] = coefs

    print(f"Found {len(embeddings_index)} word vectors.")
    return embeddings_index

def prepare_glove_embedding_matrix(text_vectorization, embeddings_index,
                                   max_tokens, embedding_dim=100):
    """Prepare GloVe embedding matrix"""
    print("Preparing GloVe embedding matrix...")

    vocabulary = text_vectorization.get_vocabulary()
    word_index = dict(zip(vocabulary, range(len(vocabulary))))

    embedding_matrix = np.zeros((max_tokens, embedding_dim))
    words_found = 0

    for word, i in word_index.items():
        if i < max_tokens:
            embedding_vector = embeddings_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector
                words_found += 1

    print(f"Found embeddings for {words_found}/{min(len(vocabulary), max_tokens)} words")
    return embedding_matrix

def build_model_with_pretrained_embedding(embedding_matrix, max_tokens, embedding_dim=100):
    """Build model with pretrained GloVe embeddings"""
    print(f"\nBuilding model with pretrained GloVe embeddings (dim={embedding_dim})...")

    embedding_layer = layers.Embedding(
        max_tokens,
        embedding_dim,
        embeddings_initializer=keras.initializers.Constant(embedding_matrix),
        trainable=False,
        mask_zero=True,
    )

    inputs = keras.Input(shape=(None,), dtype="int64")
    embedded = embedding_layer(inputs)
    x = layers.Bidirectional(layers.LSTM(32))(embedded)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = keras.Model(inputs, outputs)
    model.compile(
        optimizer="rmsprop",
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %% [markdown]
# # ===============================================
# # PART 4: TRAINING AND EVALUATION
# # ===============================================

# %%
def train_and_evaluate(model, train_ds, val_ds, test_ds, model_name, epochs=10):
    """Train and evaluate a model"""
    print(f"\n{'=' * 80}")
    print(f"Training {model_name}")
    print(f"{'=' * 80}")

    callbacks = [
        keras.callbacks.ModelCheckpoint(
            f"{model_name}.keras",
            save_best_only=True,
            monitor='val_accuracy'
        ),
        keras.callbacks.EarlyStopping(
            monitor='val_accuracy',
            patience=3,
            restore_best_weights=True
        )
    ]

    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=callbacks,
        verbose=1
    )

    # Evaluate on test set
    test_loss, test_acc = model.evaluate(test_ds, verbose=0)
    print(f"\n{model_name} - Test accuracy: {test_acc:.4f}")

    return history, test_acc

# %% [markdown]
# # =================================================
# # PART 5: COMPARISON WITH VARYING TRAINING SAMPLES
# # =================================================

# %%
def compare_training_sample_sizes(train_ds, val_ds, test_ds, text_vectorization,
                                 embeddings_index, max_tokens, max_length):
    """
    Question 2: Compare performance with different training sample sizes
    to find the crossover point where learned embeddings outperform pretrained
    """
    print("\nTesting with multiple training sample sizes to find crossover point...")
    print("This will take some time as we train models with different data sizes.")

    # Test with different training sample sizes
    sample_sizes = [50, 100, 200, 500, 1000, 2000, 5000, 10000]

    results = {
        'sample_sizes': [],
        'embedding_acc': [],
        'pretrained_acc': []
    }

    embedding_dim = 100
    embedding_matrix = prepare_glove_embedding_matrix(
        text_vectorization, embeddings_index, max_tokens, embedding_dim
    )

    for num_samples in sample_sizes:
        print(f"\n--- Testing with {num_samples} training samples ---")

        # Create limited datasets
        limited_train_ds = train_ds.map(
            lambda x, y: (text_vectorization(x), y),
            num_parallel_calls=4
        ).take(num_samples // 32 + 1)

        limited_val_ds = val_ds.map(
            lambda x, y: (text_vectorization(x), y),
            num_parallel_calls=4
        ).take(10000 // 32 + 1)

        test_ds_int = test_ds.map(
            lambda x, y: (text_vectorization(x), y),
            num_parallel_calls=4
        )

        # Train model with learned embedding
        print(f"\n1. Learned Embedding ({num_samples} samples):")
        model_emb = build_model_with_embedding(max_tokens, max_length, embedding_dim)
        _, acc_emb = train_and_evaluate(
            model_emb, limited_train_ds, limited_val_ds, test_ds_int,
            f"learned_emb_{num_samples}", epochs=10
        )

        # Train model with pretrained embedding
        print(f"\n2. Pretrained GloVe Embedding ({num_samples} samples):")
        model_glove = build_model_with_pretrained_embedding(
            embedding_matrix, max_tokens, embedding_dim
        )
        _, acc_glove = train_and_evaluate(
            model_glove, limited_train_ds, limited_val_ds, test_ds_int,
            f"pretrained_emb_{num_samples}", epochs=10
        )

        results['sample_sizes'].append(num_samples)
        results['embedding_acc'].append(acc_emb)
        results['pretrained_acc'].append(acc_glove)

        print(f"\nResults for {num_samples} samples:")
        print(f"  Learned Embedding: {acc_emb:.4f}")
        print(f"  Pretrained GloVe: {acc_glove:.4f}")
        print(f"  Winner: {'Learned' if acc_emb > acc_glove else 'Pretrained'}")

    return results

def plot_results(results):
    """Plot comparison results"""
    plt.figure(figsize=(12, 6))

    plt.plot(results['sample_sizes'], results['embedding_acc'],
             marker='o', label='Learned Embedding', linewidth=2)
    plt.plot(results['sample_sizes'], results['pretrained_acc'],
             marker='s', label='Pretrained GloVe', linewidth=2)

    plt.xlabel('Number of Training Samples', fontsize=12)
    plt.ylabel('Test Accuracy', fontsize=12)
    plt.title('Learned vs Pretrained Embeddings: Performance vs Training Data Size',
              fontsize=14, fontweight='bold')
    plt.legend(fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.xscale('log')

    # Add crossover point annotation
    for i in range(len(results['sample_sizes']) - 1):
        if (results['embedding_acc'][i] <= results['pretrained_acc'][i] and
            results['embedding_acc'][i+1] > results['pretrained_acc'][i+1]):
            plt.axvline(x=results['sample_sizes'][i], color='red',
                       linestyle='--', alpha=0.5, label='Crossover point')
            break

    plt.tight_layout()
    plt.savefig('embedding_comparison.png', dpi=300, bbox_inches='tight')
    print("\nPlot saved as 'embedding_comparison.png'")
    plt.show()

# %% [markdown]
# # =========================================
# # MAIN EXECUTION
# # =========================================

# %%
def main():
    # Prepare data
    train_ds, val_ds, test_ds = prepare_data()

    # ========================================================================
    # QUESTION 1: WHICH APPROACH WORKS BETTER?
    # ========================================================================
    print("\n" + "=" * 80)
    print("QUESTION 1: Which approach works better?")
    print("  a) Embedding layer (learned from scratch)")
    print("  b) Pretrained word embedding (GloVe)")
    print("=" * 80)

    (int_train_ds, int_val_ds, int_test_ds,
     text_vectorization, max_tokens, max_length) = prepare_limited_dataset(
        train_ds, val_ds, test_ds,
        max_length=150,
        max_tokens=10000,
        num_train_samples=100,
        num_val_samples=10000
    )

    # Build and train model with learned embedding
    print("\nTesting approach (a): Learned Embedding Layer")
    model_embedding = build_model_with_embedding(max_tokens, max_length, embedding_dim=100)
    history_emb, acc_emb = train_and_evaluate(
        model_embedding, int_train_ds, int_val_ds, int_test_ds,
        "learned_embedding_100samples", epochs=10
    )

    # Load GloVe and build model with pretrained embeddings
    print("\nTesting approach (b): Pretrained GloVe Embeddings")
    embeddings_index = load_glove_embeddings(embedding_dim=100)
    embedding_matrix = prepare_glove_embedding_matrix(
        text_vectorization, embeddings_index, max_tokens, embedding_dim=100
    )

    model_pretrained = build_model_with_pretrained_embedding(
        embedding_matrix, max_tokens, embedding_dim=100
    )
    history_pre, acc_pre = train_and_evaluate(
        model_pretrained, int_train_ds, int_val_ds, int_test_ds,
        "pretrained_embedding_100samples", epochs=10
    )

    # Print comparison for Question 1
    print("\n" + "=" * 80)
    print("QUESTION 1: WHICH APPROACH WORKS BETTER?")
    print("=" * 80)
    print("\nConfiguration:")
    print("  - Reviews cutoff: 150 words")
    print("  - Training samples: 100")
    print("  - Validation samples: 10,000")
    print("  - Top words considered: 10,000")
    print("\nResults:")
    print(f"  a) Learned Embedding Test Accuracy:    {acc_emb:.4f}")
    print(f"  b) Pretrained GloVe Test Accuracy:     {acc_pre:.4f}")


    # ========================================================================
    # QUESTION 2: AT WHAT POINT DOES LEARNED EMBEDDING GIVE BETTER PERFORMANCE?
    # ========================================================================
    print("\n\n" + "=" * 80)
    print("QUESTION 2: Now try changing the number of training samples to")
    print("            determine at what point the embedding layer gives")
    print("            better performance.")
    print("=" * 80)

    # Question 2: Vary training sample sizes
    results = compare_training_sample_sizes(
        train_ds, val_ds, test_ds, text_vectorization,
        embeddings_index, max_tokens, max_length
    )

    # Plot results
    plot_results(results)

    # Summary
    print("\n" + "=" * 80)
    print("QUESTION 2: AT WHAT POINT DOES LEARNED EMBEDDING GIVE BETTER PERFORMANCE?")
    print("=" * 80)

    print("\nResults Table:")
    print("-" * 80)
    print(f"{'Training Samples':<20} {'Learned Emb':<15} {'Pretrained Emb':<15} {'Winner':<15}")
    print("-" * 80)
    for i, size in enumerate(results['sample_sizes']):
        learned = results['embedding_acc'][i]
        pretrained = results['pretrained_acc'][i]
        winner = "Learned" if learned > pretrained else "Pretrained"
        print(f"{size:<20} {learned:<15.4f} {pretrained:<15.4f} {winner:<15}")
    print("-" * 80)

    print("\n" + "-" * 80)
    print("ANSWER TO QUESTION 2:")
    print("-" * 80)

    crossover_found = False
    crossover_point = None

    for i in range(len(results['sample_sizes']) - 1):
        if (results['pretrained_acc'][i] >= results['embedding_acc'][i] and
            results['pretrained_acc'][i+1] < results['embedding_acc'][i+1]):
            crossover_point = results['sample_sizes'][i+1]
            crossover_found = True
            break

    if crossover_found:
        print(f"✓ The crossover point is around {crossover_point} training samples")
        print(f"\n  Below {crossover_point} samples: Pretrained embeddings perform better")
        print(f"  At/above {crossover_point} samples: Learned embeddings start to perform better")
        print("\nExplanation:")
        print(f"  With fewer than ~{crossover_point} samples, pretrained embeddings win because")
        print("  they contain prior knowledge about word meanings and relationships.")
        print(f"  With {crossover_point}+ samples, there's enough task-specific data for the")
        print("  learned embeddings to adapt to the sentiment analysis task and potentially")
        print("  outperform the generic pretrained embeddings.")
    else:
        if results['embedding_acc'][-1] > results['pretrained_acc'][-1]:
            print(f"✓ Learned embeddings become competitive around {results['sample_sizes'][-1]} samples")
            print(f"  but may need even more data to consistently outperform pretrained embeddings")
        else:
            print(f"✓ Even with {results['sample_sizes'][-1]} training samples, pretrained embeddings")
            print("  continue to outperform learned embeddings")
            print("\nExplanation:")
            print("  This suggests that for this specific task (IMDB sentiment analysis),")
            print("  pretrained embeddings provide strong baseline performance that is hard")
            print("  to exceed even with moderate amounts of training data. More samples")
            print(f"  (possibly >5000) would be needed for learned embeddings to catch up.")
    print("-" * 80)

    print("\n" + "=" * 80)
    print("=" * 80)

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# PART 1: DATA PREPARATION
# ================================================================================
# Downloading IMDB dataset...
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.
# Found 25000 files belonging to 2 classes.
#
# ================================================================================
# QUESTION 1: Which approach works better?
#   a) Embedding layer (learned from scratch)
#   b) Pretrained word embedding (GloVe)
# ================================================================================
#
# Preparing limited dataset:
#   Max sequence length: 150
#   Max tokens: 10000
#   Training samples: 100
#   Validation samples: 10000
#
# Testing approach (a): Learned Embedding Layer
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_embedding_100samples
# ================================================================================
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 5s 520ms/step - accuracy: 0.3906 - loss: 0.6954 - val_accuracy: 0.5188 - val_loss: 0.6928
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 341ms/step - accuracy: 0.5271 - loss: 0.6905 - val_accuracy: 0.5052 - val_loss: 0.6925
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.6031 - loss: 0.6889 - val_accuracy: 0.5054 - val_loss: 0.6925
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - accuracy: 0.5573 - loss: 0.6849 - val_accuracy: 0.5258 - val_loss: 0.6921
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 0.6427 - loss: 0.6823 - val_accuracy: 0.5058 - val_loss: 0.6922
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.5844 - loss: 0.6777 - val_accuracy: 0.5094 - val_loss: 0.6918
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.5615 - loss: 0.6802 - val_accuracy: 0.5172 - val_loss: 0.6913
#
# learned_embedding_100samples - Test accuracy: 0.5204
#
# Testing approach (b): Pretrained GloVe Embeddings
# Downloading GloVe embeddings...
# Loading GloVe embeddings from glove.6B.100d.txt...
# Found 400000 word vectors.
# Preparing GloVe embedding matrix...
# Found embeddings for 9683/10000 words
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_embedding_100samples
# ================================================================================
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 958ms/step - accuracy: 0.5396 - loss: 0.7279 - val_accuracy: 0.5504 - val_loss: 0.6874
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - accuracy: 0.4583 - loss: 0.7124 - val_accuracy: 0.5460 - val_loss: 0.6862
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.5708 - loss: 0.6832 - val_accuracy: 0.5138 - val_loss: 0.6959
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 811ms/step - accuracy: 0.5531 - loss: 0.6771 - val_accuracy: 0.5700 - val_loss: 0.6825
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.5708 - loss: 0.6668 - val_accuracy: 0.5252 - val_loss: 0.6894
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.4802 - loss: 0.7059 - val_accuracy: 0.5348 - val_loss: 0.6870
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.5698 - loss: 0.6715 - val_accuracy: 0.5452 - val_loss: 0.6852
#
# pretrained_embedding_100samples - Test accuracy: 0.5583
#
# ================================================================================
# QUESTION 1: WHICH APPROACH WORKS BETTER?
# ================================================================================
#
# Configuration:
#   - Reviews cutoff: 150 words
#   - Training samples: 100
#   - Validation samples: 10,000
#   - Top words considered: 10,000
#
# Results:
#   a) Learned Embedding Test Accuracy:    0.5204
#   b) Pretrained GloVe Test Accuracy:     0.5583
#
#
# ================================================================================
# QUESTION 2: Now try changing the number of training samples to
#             determine at what point the embedding layer gives
#             better performance.
# ================================================================================
#
# Testing with multiple training sample sizes to find crossover point...
# This will take some time as we train models with different data sizes.
# Preparing GloVe embedding matrix...
# Found embeddings for 9683/10000 words
#
# --- Testing with 50 training samples ---
#
# 1. Learned Embedding (50 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_50
# ================================================================================
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.4375 - loss: 0.6933 - val_accuracy: 0.4996 - val_loss: 0.6934
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 985ms/step - accuracy: 0.5208 - loss: 0.6911 - val_accuracy: 0.5012 - val_loss: 0.6933
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step - accuracy: 0.6042 - loss: 0.6880 - val_accuracy: 0.5000 - val_loss: 0.6936
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step - accuracy: 0.4167 - loss: 0.6944 - val_accuracy: 0.5118 - val_loss: 0.6929
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step - accuracy: 0.5938 - loss: 0.6895 - val_accuracy: 0.5114 - val_loss: 0.6928
# Epoch 6/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step - accuracy: 0.5833 - loss: 0.6888 - val_accuracy: 0.5106 - val_loss: 0.6927
# Epoch 7/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 988ms/step - accuracy: 0.6667 - loss: 0.6836 - val_accuracy: 0.5142 - val_loss: 0.6926
# Epoch 8/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step - accuracy: 0.6771 - loss: 0.6851 - val_accuracy: 0.5130 - val_loss: 0.6925
# Epoch 9/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 934ms/step - accuracy: 0.6979 - loss: 0.6818 - val_accuracy: 0.5090 - val_loss: 0.6925
# Epoch 10/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 980ms/step - accuracy: 0.6146 - loss: 0.6798 - val_accuracy: 0.5122 - val_loss: 0.6923
#
# learned_emb_50 - Test accuracy: 0.5058
#
# 2. Pretrained GloVe Embedding (50 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_50
# ================================================================================
# Epoch 1/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 3s/step - accuracy: 0.5312 - loss: 0.7506 - val_accuracy: 0.5004 - val_loss: 0.6979
# Epoch 2/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.5729 - loss: 0.7146 - val_accuracy: 0.5072 - val_loss: 0.6988
# Epoch 3/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step - accuracy: 0.5208 - loss: 0.7108 - val_accuracy: 0.5002 - val_loss: 0.7104
# Epoch 4/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.5208 - loss: 0.7357 - val_accuracy: 0.5014 - val_loss: 0.7075
# Epoch 5/10
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.4688 - loss: 0.7248 - val_accuracy: 0.5034 - val_loss: 0.6953
#
# pretrained_emb_50 - Test accuracy: 0.5098
#
# Results for 50 samples:
#   Learned Embedding: 0.5058
#   Pretrained GloVe: 0.5098
#   Winner: Pretrained
#
# --- Testing with 100 training samples ---
#
# 1. Learned Embedding (100 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_100
# ================================================================================
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 472ms/step - accuracy: 0.5042 - loss: 0.6936 - val_accuracy: 0.5116 - val_loss: 0.6930
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.5458 - loss: 0.6922 - val_accuracy: 0.5036 - val_loss: 0.6929
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.5542 - loss: 0.6905 - val_accuracy: 0.5058 - val_loss: 0.6928
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - accuracy: 0.6396 - loss: 0.6870 - val_accuracy: 0.5092 - val_loss: 0.6926
#
# learned_emb_100 - Test accuracy: 0.5126
#
# 2. Pretrained GloVe Embedding (100 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_100
# ================================================================================
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step - accuracy: 0.5000 - loss: 0.7220 - val_accuracy: 0.5014 - val_loss: 0.6985
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 866ms/step - accuracy: 0.5375 - loss: 0.7064 - val_accuracy: 0.5380 - val_loss: 0.6890
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 852ms/step - accuracy: 0.5990 - loss: 0.6669 - val_accuracy: 0.5476 - val_loss: 0.6875
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.4479 - loss: 0.7144 - val_accuracy: 0.5076 - val_loss: 0.6970
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.5281 - loss: 0.6916 - val_accuracy: 0.5460 - val_loss: 0.6857
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.5667 - loss: 0.7046 - val_accuracy: 0.5468 - val_loss: 0.6847
#
# pretrained_emb_100 - Test accuracy: 0.5441
#
# Results for 100 samples:
#   Learned Embedding: 0.5126
#   Pretrained GloVe: 0.5441
#   Winner: Pretrained
#
# --- Testing with 200 training samples ---
#
# 1. Learned Embedding (200 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_200
# ================================================================================
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 240ms/step - accuracy: 0.4966 - loss: 0.6926 - val_accuracy: 0.5066 - val_loss: 0.6928
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.5440 - loss: 0.6896 - val_accuracy: 0.5112 - val_loss: 0.6925
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 186ms/step - accuracy: 0.6238 - loss: 0.6864 - val_accuracy: 0.5258 - val_loss: 0.6919
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.6294 - loss: 0.6846 - val_accuracy: 0.5386 - val_loss: 0.6912
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - accuracy: 0.7096 - loss: 0.6783 - val_accuracy: 0.5474 - val_loss: 0.6901
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.7540 - loss: 0.6714 - val_accuracy: 0.5502 - val_loss: 0.6884
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7425 - loss: 0.6662 - val_accuracy: 0.5386 - val_loss: 0.6866
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - accuracy: 0.7205 - loss: 0.6343 - val_accuracy: 0.5944 - val_loss: 0.6731
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step - accuracy: 0.7645 - loss: 0.6081 - val_accuracy: 0.5880 - val_loss: 0.6689
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 174ms/step - accuracy: 0.7728 - loss: 0.5419 - val_accuracy: 0.6672 - val_loss: 0.6140
#
# learned_emb_200 - Test accuracy: 0.6640
#
# 2. Pretrained GloVe Embedding (200 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_200
# ================================================================================
# Epoch 1/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 473ms/step - accuracy: 0.5432 - loss: 0.7266 - val_accuracy: 0.5108 - val_loss: 0.6952
# Epoch 2/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 413ms/step - accuracy: 0.5160 - loss: 0.7070 - val_accuracy: 0.5218 - val_loss: 0.6913
# Epoch 3/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 456ms/step - accuracy: 0.5162 - loss: 0.7121 - val_accuracy: 0.5314 - val_loss: 0.6922
# Epoch 4/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 428ms/step - accuracy: 0.4938 - loss: 0.7027 - val_accuracy: 0.5410 - val_loss: 0.6870
# Epoch 5/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 428ms/step - accuracy: 0.5282 - loss: 0.6868 - val_accuracy: 0.5508 - val_loss: 0.6840
# Epoch 6/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 411ms/step - accuracy: 0.5391 - loss: 0.6875 - val_accuracy: 0.5510 - val_loss: 0.6857
# Epoch 7/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 452ms/step - accuracy: 0.6357 - loss: 0.6543 - val_accuracy: 0.5650 - val_loss: 0.6786
# Epoch 8/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - accuracy: 0.5914 - loss: 0.6760 - val_accuracy: 0.5874 - val_loss: 0.6744
# Epoch 9/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 415ms/step - accuracy: 0.5592 - loss: 0.6606 - val_accuracy: 0.5920 - val_loss: 0.6720
# Epoch 10/10
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.6372 - loss: 0.6454 - val_accuracy: 0.5904 - val_loss: 0.6691
#
# pretrained_emb_200 - Test accuracy: 0.5927
#
# Results for 200 samples:
#   Learned Embedding: 0.6640
#   Pretrained GloVe: 0.5927
#   Winner: Learned
#
# --- Testing with 500 training samples ---
#
# 1. Learned Embedding (500 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_500
# ================================================================================
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step - accuracy: 0.5461 - loss: 0.6928 - val_accuracy: 0.5118 - val_loss: 0.6928
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - accuracy: 0.5906 - loss: 0.6899 - val_accuracy: 0.5428 - val_loss: 0.6920
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.6647 - loss: 0.6852 - val_accuracy: 0.5464 - val_loss: 0.6905
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7092 - loss: 0.6763 - val_accuracy: 0.5760 - val_loss: 0.6860
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.7603 - loss: 0.6511 - val_accuracy: 0.6354 - val_loss: 0.6588
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - accuracy: 0.7436 - loss: 0.5795 - val_accuracy: 0.7028 - val_loss: 0.5993
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7533 - loss: 0.5392 - val_accuracy: 0.6926 - val_loss: 0.5867
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.8322 - loss: 0.4253 - val_accuracy: 0.6736 - val_loss: 0.6030
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.9299 - loss: 0.2514 - val_accuracy: 0.7002 - val_loss: 0.5686
#
# learned_emb_500 - Test accuracy: 0.6994
#
# 2. Pretrained GloVe Embedding (500 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_500
# ================================================================================
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.4847 - loss: 0.7188 - val_accuracy: 0.5272 - val_loss: 0.6897
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 179ms/step - accuracy: 0.5735 - loss: 0.6825 - val_accuracy: 0.5454 - val_loss: 0.6853
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.5895 - loss: 0.6651 - val_accuracy: 0.5680 - val_loss: 0.6788
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.5924 - loss: 0.6680 - val_accuracy: 0.5046 - val_loss: 0.7075
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 190ms/step - accuracy: 0.6096 - loss: 0.6558 - val_accuracy: 0.6250 - val_loss: 0.6559
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 183ms/step - accuracy: 0.6436 - loss: 0.6334 - val_accuracy: 0.6500 - val_loss: 0.6345
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 3s 173ms/step - accuracy: 0.7062 - loss: 0.5893 - val_accuracy: 0.6660 - val_loss: 0.6209
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.7058 - loss: 0.5882 - val_accuracy: 0.6516 - val_loss: 0.6203
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - accuracy: 0.6821 - loss: 0.6036 - val_accuracy: 0.6542 - val_loss: 0.6190
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.7237 - loss: 0.5727 - val_accuracy: 0.5940 - val_loss: 0.6689
#
# pretrained_emb_500 - Test accuracy: 0.6561
#
# Results for 500 samples:
#   Learned Embedding: 0.6994
#   Pretrained GloVe: 0.6561
#   Winner: Learned
#
# --- Testing with 1000 training samples ---
#
# 1. Learned Embedding (1000 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_1000
# ================================================================================
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.4871 - loss: 0.6938 - val_accuracy: 0.5098 - val_loss: 0.6912
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.5686 - loss: 0.6844 - val_accuracy: 0.5428 - val_loss: 0.6801
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.6360 - loss: 0.6406 - val_accuracy: 0.6902 - val_loss: 0.6101
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.7897 - loss: 0.5091 - val_accuracy: 0.7542 - val_loss: 0.5233
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.8635 - loss: 0.3716 - val_accuracy: 0.7710 - val_loss: 0.4947
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.8710 - loss: 0.3374 - val_accuracy: 0.6020 - val_loss: 0.9981
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.9104 - loss: 0.2355 - val_accuracy: 0.7122 - val_loss: 0.6756
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9244 - loss: 0.2028 - val_accuracy: 0.7708 - val_loss: 0.5040
#
# learned_emb_1000 - Test accuracy: 0.7536
#
# 2. Pretrained GloVe Embedding (1000 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_1000
# ================================================================================
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.4640 - loss: 0.7348 - val_accuracy: 0.5572 - val_loss: 0.6859
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.5381 - loss: 0.6864 - val_accuracy: 0.5924 - val_loss: 0.6757
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5287 - loss: 0.6847 - val_accuracy: 0.5780 - val_loss: 0.6718
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.6267 - loss: 0.6523 - val_accuracy: 0.6406 - val_loss: 0.6453
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.6384 - loss: 0.6427 - val_accuracy: 0.6542 - val_loss: 0.6268
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6783 - loss: 0.6107 - val_accuracy: 0.6784 - val_loss: 0.6048
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step - accuracy: 0.6920 - loss: 0.5882 - val_accuracy: 0.6892 - val_loss: 0.5922
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - accuracy: 0.7194 - loss: 0.5627 - val_accuracy: 0.7020 - val_loss: 0.5766
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - accuracy: 0.7330 - loss: 0.5373 - val_accuracy: 0.7042 - val_loss: 0.5732
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - accuracy: 0.7320 - loss: 0.5425 - val_accuracy: 0.7104 - val_loss: 0.5637
#
# pretrained_emb_1000 - Test accuracy: 0.7100
#
# Results for 1000 samples:
#   Learned Embedding: 0.7536
#   Pretrained GloVe: 0.7100
#   Winner: Learned
#
# --- Testing with 2000 training samples ---
#
# 1. Learned Embedding (2000 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_2000
# ================================================================================
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.4925 - loss: 0.6932 - val_accuracy: 0.5250 - val_loss: 0.6900
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.6153 - loss: 0.6769 - val_accuracy: 0.7074 - val_loss: 0.5831
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7168 - loss: 0.5570 - val_accuracy: 0.7794 - val_loss: 0.4738
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8250 - loss: 0.4032 - val_accuracy: 0.7560 - val_loss: 0.5027
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8911 - loss: 0.3115 - val_accuracy: 0.7790 - val_loss: 0.4704
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.9250 - loss: 0.2308 - val_accuracy: 0.7634 - val_loss: 0.5230
#
# learned_emb_2000 - Test accuracy: 0.7821
#
# 2. Pretrained GloVe Embedding (2000 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_2000
# ================================================================================
# Epoch 1/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.4995 - loss: 0.7252 - val_accuracy: 0.5894 - val_loss: 0.6743
# Epoch 2/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.5703 - loss: 0.6794 - val_accuracy: 0.6008 - val_loss: 0.6545
# Epoch 3/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.6303 - loss: 0.6412 - val_accuracy: 0.6028 - val_loss: 0.6715
# Epoch 4/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.6868 - loss: 0.6073 - val_accuracy: 0.7050 - val_loss: 0.5859
# Epoch 5/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7083 - loss: 0.5661 - val_accuracy: 0.6822 - val_loss: 0.6122
# Epoch 6/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7046 - loss: 0.5961 - val_accuracy: 0.6894 - val_loss: 0.5851
# Epoch 7/10
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.7423 - loss: 0.5380 - val_accuracy: 0.6744 - val_loss: 0.6077
#
# pretrained_emb_2000 - Test accuracy: 0.6955
#
# Results for 2000 samples:
#   Learned Embedding: 0.7821
#   Pretrained GloVe: 0.6955
#   Winner: Learned
#
# --- Testing with 5000 training samples ---
#
# 1. Learned Embedding (5000 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_5000
# ================================================================================
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.5224 - loss: 0.6878 - val_accuracy: 0.6794 - val_loss: 0.5888
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7195 - loss: 0.5441 - val_accuracy: 0.7982 - val_loss: 0.4351
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.8371 - loss: 0.3791 - val_accuracy: 0.8056 - val_loss: 0.4375
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.8802 - loss: 0.3003 - val_accuracy: 0.7996 - val_loss: 0.4419
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9093 - loss: 0.2342 - val_accuracy: 0.7594 - val_loss: 0.5748
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.9281 - loss: 0.1960 - val_accuracy: 0.7652 - val_loss: 0.6314
#
# learned_emb_5000 - Test accuracy: 0.7882
#
# 2. Pretrained GloVe Embedding (5000 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_5000
# ================================================================================
# Epoch 1/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.5241 - loss: 0.7003 - val_accuracy: 0.6604 - val_loss: 0.6308
# Epoch 2/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.6657 - loss: 0.6231 - val_accuracy: 0.6804 - val_loss: 0.5958
# Epoch 3/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7074 - loss: 0.5693 - val_accuracy: 0.6542 - val_loss: 0.6370
# Epoch 4/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.7307 - loss: 0.5522 - val_accuracy: 0.7652 - val_loss: 0.4938
# Epoch 5/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.7473 - loss: 0.5167 - val_accuracy: 0.7836 - val_loss: 0.4705
# Epoch 6/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.7797 - loss: 0.4797 - val_accuracy: 0.6810 - val_loss: 0.6660
# Epoch 7/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7731 - loss: 0.4780 - val_accuracy: 0.7640 - val_loss: 0.4938
# Epoch 8/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.7955 - loss: 0.4538 - val_accuracy: 0.7958 - val_loss: 0.4489
# Epoch 9/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.7946 - loss: 0.4376 - val_accuracy: 0.7852 - val_loss: 0.4855
# Epoch 10/10
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.8114 - loss: 0.4214 - val_accuracy: 0.7798 - val_loss: 0.4672
#
# pretrained_emb_5000 - Test accuracy: 0.7929
#
# Results for 5000 samples:
#   Learned Embedding: 0.7882
#   Pretrained GloVe: 0.7929
#   Winner: Pretrained
#
# --- Testing with 10000 training samples ---
#
# 1. Learned Embedding (10000 samples):
#
# Building model with learned embedding (dim=100)...
#
# ================================================================================
# Training learned_emb_10000
# ================================================================================
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.5695 - loss: 0.6669 - val_accuracy: 0.6402 - val_loss: 0.7938
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8018 - loss: 0.4418 - val_accuracy: 0.8354 - val_loss: 0.3974
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8537 - loss: 0.3461 - val_accuracy: 0.8370 - val_loss: 0.3714
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8846 - loss: 0.2883 - val_accuracy: 0.8282 - val_loss: 0.4098
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9079 - loss: 0.2374 - val_accuracy: 0.7844 - val_loss: 0.4857
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9209 - loss: 0.2033 - val_accuracy: 0.8326 - val_loss: 0.4132
#
# learned_emb_10000 - Test accuracy: 0.8290
#
# 2. Pretrained GloVe Embedding (10000 samples):
#
# Building model with pretrained GloVe embeddings (dim=100)...
#
# ================================================================================
# Training pretrained_emb_10000
# ================================================================================
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.5567 - loss: 0.6868 - val_accuracy: 0.7288 - val_loss: 0.5635
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7111 - loss: 0.5697 - val_accuracy: 0.7358 - val_loss: 0.5360
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7544 - loss: 0.5125 - val_accuracy: 0.7878 - val_loss: 0.4644
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7696 - loss: 0.4793 - val_accuracy: 0.7896 - val_loss: 0.4491
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7991 - loss: 0.4493 - val_accuracy: 0.7374 - val_loss: 0.5353
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8046 - loss: 0.4407 - val_accuracy: 0.7950 - val_loss: 0.4303
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8176 - loss: 0.4157 - val_accuracy: 0.8016 - val_loss: 0.4358
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8182 - loss: 0.4092 - val_accuracy: 0.8128 - val_loss: 0.4100
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8332 - loss: 0.3845 - val_accuracy: 0.8112 - val_loss: 0.4170
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8409 - loss: 0.3710 - val_accuracy: 0.8066 - val_loss: 0.4175
#
# pretrained_emb_10000 - Test accuracy: 0.8108
#
# Results for 10000 samples:
#   Learned Embedding: 0.8290
#   Pretrained GloVe: 0.8108
#   Winner: Learned
#
# Plot saved as 'embedding_comparison.png'
# ================================================================================
# QUESTION 2: AT WHAT POINT DOES LEARNED EMBEDDING GIVE BETTER PERFORMANCE?
# ================================================================================
#
# Results Table:
# --------------------------------------------------------------------------------
# Training Samples     Learned Emb     Pretrained Emb  Winner
# --------------------------------------------------------------------------------
# 50                   0.5058          0.5098          Pretrained
# 100                  0.5126          0.5441          Pretrained
# 200                  0.6640          0.5927          Learned
# 500                  0.6994          0.6561          Learned
# 1000                 0.7536          0.7100          Learned
# 2000                 0.7821          0.6955          Learned
# 5000                 0.7882          0.7929          Pretrained
# 10000                0.8290          0.8108          Learned
# --------------------------------------------------------------------------------
#
# --------------------------------------------------------------------------------
# ANSWER TO QUESTION 2:
# --------------------------------------------------------------------------------
# ✓ The crossover point is around 200 training samples
#
#   Below 200 samples: Pretrained embeddings perform better
#   At/above 200 samples: Learned embeddings start to perform better
#
# Explanation:
#   With fewer than ~200 samples, pretrained embeddings win because
#   they contain prior knowledge about word meanings and relationships.
#   With 200+ samples, there's enough task-specific data for the
#   learned embeddings to adapt to the sentiment analysis task and potentially
#   outperform the generic pretrained embeddings.
# --------------------------------------------------------------------------------
#
# ================================================================================
# ================================================================================
